# %% [markdown]
# # Assignment Block 1 - Matplotlib
# We use the Big-Mart Data for some plotting exercises
#
# <img src="IMG/BigMarket.jpg" width=400>
#
# Details on the dataset: https://www.kaggle.com/shivan118/big-mart-sales-prediction-datasets

# %%
#import an read big-mart data
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

#Read data into pandas table - details on pandas in block 3
data = pd.read_csv("../../DATA/company_sales_data.csv")

# %%
#short preview of the data table
data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
#access data rows by name
plt.plot(data.toothpaste)

# %% [markdown]
# ## Exercise 1
# Read Total profit of all months and show it using a line plot
# Total profit data provided for each month. Generated line plot must include the following properties:
#
# * X label name = Month Number
# * Y label name = Total profit
#
# ### The result should look something like this:
# <img src="IMG/1.png" width=400>

# %%
import numpy as np
fig, axes = plt.subplots()
axes.plot(data.month_number,data.total_profit)
axes.set_title('Company profit per month')
axes.set_ylim([100000,500000])
axes.set_yticks(np.arange(100000,600000,100000))
axes.set_xlabel("Month number")
axes.set_ylabel("Total profit")
# Out:
# Text(0, 0.5, 'Total profit')

# %% [markdown]
# ## Exercise 2
# Get Total profit of all months and show line plot with the following Style properties
# Generated line plot must include following Style properties:
#
# * Line Style dotted and Line color should be red
# * Show legend at the lower right location.
# * X label name = Month Number
# * Y label name = Sold units number
# * Add a circle marker.
# * Line marker color as read
# * Line width should be 3
#
#
# ### The result should look something like this:
# <img src="IMG/2.png" width=400>

# %%
fig, axes = plt.subplots()
axes.plot(data.month_number,data.total_profit,color='red', label='Profit data of last year',lw=3,ls='--',marker='o',markerfacecolor="blue")
axes.set_title('Company profit per month')
axes.set_ylim([100000,500000])
axes.set_yticks(np.arange(100000,600000,100000))
axes.set_xticks(np.arange(1,13,1))
axes.set_xlabel("Month number")
axes.set_ylabel("Total profit")
axes.legend(loc=4)

# %% [markdown]
# ## Exercise 3
# Read all product sales data and show it  using a multiline plot
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product for each product).
#
#
# ### The result should look something like this:
# <img src="IMG/3.png" width=400>

# %%
fig,axes = plt.subplots()
product_cols = range(1,7,1)
product_list = list(data.head(0))[1:len(list(data.head(0)))-2]
for product in product_list:
    axes.plot(data.month_number,data.loc[:,product],marker='o',label=product,lw=3)
axes.legend(loc=2)
axes.set_xticks(range(1,13,1))
axes.set_yticks([1000,2000,4000,6000,8000,10000,12000,15000,18000])
axes.set_ylabel('sales units in number')
axes.set_xlabel('Month number')
axes.set_title('Sales data')
# Out:
# Text(0.5, 1.0, 'Sales data')

# %% [markdown]
# ## Exercise 4
# Read toothpaste sales data of each month and show it using a scatter plot
# Also, add a grid in the plot.
#
#
# ### The result should look something like this:
# <img src="IMG/4.png" width=400>

# %%
fig,axes = plt.subplots()
axes.scatter(data.month_number,data.toothpaste, label='Tooth paste Sales data')
axes.legend()
axes.set_title('Tooth paste Sales data')
axes.set_ylabel('Number of units Sold')
axes.set_xlabel('Month Number')
axes.set_xticks(np.arange(1,13,1))
axes.grid(linestyle='dashed')

# %% [markdown]
# ## Exercise 5
# Read face cream and facewash product sales data and show it using the bar chart
# Bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.
#
#
# ### The result should look something like this:
# <img src="IMG/5.png" width=400>

# %%
fig,axes=plt.subplots()
axes.grid(linestyle='dashed')
axes.set_ylabel('Sales units in number')
axes.set_xlabel('Month Number')
axes.set_title('Facewash and facecream sales data')
width=0.2
axes.bar(data.month_number-width/2,data.facecream,width,label='Face cream sales data')
axes.bar(data.month_number+width/2,data.facewash,width,label='Face Wash sales data')
axes.legend(loc=2)
axes.set_xticks(range(1,13,1))
# Out:
# [<matplotlib.axis.XTick at 0x7fa7217a7c50>,
#  <matplotlib.axis.XTick at 0x7fa7217a7410>,
#  <matplotlib.axis.XTick at 0x7fa7217a71d0>,
#  <matplotlib.axis.XTick at 0x7fa71f694350>,
#  <matplotlib.axis.XTick at 0x7fa71f694910>,
#  <matplotlib.axis.XTick at 0x7fa71f694e90>,
#  <matplotlib.axis.XTick at 0x7fa71f69d490>,
#  <matplotlib.axis.XTick at 0x7fa71f69da10>,
#  <matplotlib.axis.XTick at 0x7fa71f69d1d0>,
#  <matplotlib.axis.XTick at 0x7fa71f6947d0>,
#  <matplotlib.axis.XTick at 0x7fa71f6a4510>,
#  <matplotlib.axis.XTick at 0x7fa71f6a4b50>]

# %% [markdown]
# ## Exercise 6
# Calculate total sale data for last year for each product and show it using a Pie chart
# Note: In Pie chart display Number of units sold per year for each product in percentage.
#
# ***Note:*** use ``data[item].sum()`` to compute sums over columns
#
#
# ### The result should look something like this:
# <img src="IMG/6.png" width=400>

# %%
data['toothpaste'].sum()
# Out:
# 69910

# %%
fig,axes=plt.subplots()
product_list = list(data.head(0))[1:len(list(data.head(0)))-2]
labels=[]
sizes=[]
for product in product_list:
    sizes.append(data[product].sum())
    labels.append(product)
#Alternativ 
#labels =["FaceCream","FaceWash","Toothpaste","Bathing soap","Shampoo","Moisturizer"]
axes.pie(sizes,labels=labels,autopct='%1.1f%%')
axes.legend(loc=4)
axes.set_title('Sales data')
# Out:
# Text(0.5, 1.0, 'Sales data')
